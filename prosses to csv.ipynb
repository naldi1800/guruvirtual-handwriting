# %%
import os
import fun
import numpy as np
import pandas as pd
from PIL import Image

# %%
paths = ["Kelas 1 40", "Kelas 2 8", "Kelas 3 46", "Kelas 2 X"]

# %%
for path in paths:
    
    output_dir_raw = f"RawData/{path}/"
    output_dir = f"Data/{path}"

    # Gather all file names in the directory
    file_names = [f for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]

    # List to hold each row: [filename, pixel0, pixel1, ...]
    rows = []

    for fname in file_names:
        # Load image and convert to grayscale or RGB array
        img_path = os.path.join(output_dir, fname)
        flat = fun.load_pixel(img_path)

        # Prepend filename and append to rows
        rows.append([fname] + flat.tolist())

    # Determine number of pixel columns (assumes all images same size & channels)
    num_pixels = len(rows[0]) - 1

    # Create column names: first column for filename, then pixel_0, pixel_1, ...
    columns = ["filename"] + [f"pixel_{i}" for i in range(num_pixels)]

    # Create DataFrame and save to CSV
    df = pd.DataFrame(rows, columns=columns)
    csv_output = os.path.join(f"{path}.csv")
    df.to_csv(csv_output, index=False)

    print(f"Saved pixel data for {len(rows)} images to {csv_output}")
# Out:
# Saved pixel data for 585 images to Kelas 1 40.csv
# Saved pixel data for 120 images to Kelas 2 8.csv
# Saved pixel data for 690 images to Kelas 3 46.csv
# Saved pixel data for 85 images to Kelas 2 X.csv

# %%
csv_path = paths[0]+".csv"
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    filename   pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5  \
# 0   0_1.png  0.968627  0.964706  0.960784  0.960784  0.964706  0.968627
# 1  0_10.png  0.968627  0.968627  0.968627  0.968627  0.968627  0.972549
# 2  0_11.png  0.956863  0.956863  0.960784  0.960784  0.960784  0.964706
# 3  0_12.png  0.972549  0.976471  0.972549  0.972549  0.972549  0.972549
# 4  0_13.png  0.972549  0.976471  0.976471  0.976471  0.972549  0.968627
#
#     pixel_6   pixel_7   pixel_8  ...  pixel_1215  pixel_1216  pixel_1217  \
# 0  0.964706  0.964706  0.968627  ...    0.976471    0.976471    0.980392
# 1  0.972549  0.972549  0.964706  ...    0.988235    0.984314    0.988235
# 2  0.968627  0.968627  0.968627  ...    0.984314    0.984314    0.988235
# 3  0.972549  0.976471  0.976471  ...    0.992157    0.992157    0.992157
# 4  0.972549  0.972549  0.968627  ...    0.992157    0.992157    0.992157
#
#    pixel_1218  pixel_1219  pixel_1220  pixel_1221  pixel_1222  pixel_1223  \
# 0    0.980392    0.980392    0.984314    0.984314    0.988235    0.988235
# 1    0.992157    0.988235    0.988235    0.992157    0.992157    0.992157
# 2    0.992157    0.992157    0.992157    0.996078    0.996078    0.992157
# 3    0.992157    0.992157    0.996078    0.996078    0.996078    0.992157
# 4    0.992157    0.992157    0.996078    0.996078    0.996078    0.992157
#
#    pixel_1224
# 0    0.988235
# 1    0.992157
# 2    0.992157
# 3    0.992157
# 4    0.992157
#
# [5 rows x 1226 columns]
